# %%
from template import Strategy
import pandas as pd

strat = Strategy()

game = pd.read_json("example-game.json")

movecol = game.pop("event_type")

game.insert(0, "event_type", movecol)

game
# Out:
#         event_type home_away  home_score  away_score player_name  \
# 0     START_PERIOD   unknown           0           0        None
# 1        JUMP_BALL      home           0           0   Player 10
# 2          NOTHING   unknown           0           0        None
# 3          NOTHING   unknown           0           0        None
# 4          NOTHING   unknown           0           0        None
# ...            ...       ...         ...         ...         ...
# 3052       NOTHING   unknown         106         102        None
# 3053       NOTHING   unknown         106         102        None
# 3054        MISSED      away         106         102   Player 13
# 3055       REBOUND      away         106         102   Player 15
# 3056      END_GAME   unknown         106         102        None
#
#      substituted_player_name    shot_type assist_player rebound_type  \
# 0                       None         None          None         None
# ...

# %%
for i in range(len(game.index)-1):
    strat.on_game_event_update(*game.loc[i])
# Out:
# START_PERIOD 0 - 0
# JUMP_BALL 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# MISSED 0 - 0
# REBOUND 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# NOTHING 0 - 0
# SCORE 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# NOTHING 0 - 2
# SCORE 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# NOTHING 2 - 2
# ...

# %%
strat.scorebook
# Out:
# [[np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(0)],
#  [np.int64(0), np.int64(2)],
#  [np.int64(0), np.int64(2)],
#  [np.int64(0), np.int64(2)],
#  [np.int64(0), np.int64(2)],
#  [np.int64(0), np.int64(2)],
#  [np.int64(0), np.int64(2)],
#  [np.int64(0), np.int64(2)],
#  [np.int64(0), np.int64(2)],
# ...
